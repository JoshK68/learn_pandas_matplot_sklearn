# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshK68/learn_pandas_matplot_sklearn/blob/main/pandas/pandas2_loc_iloc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
netflix = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/netflix_titles.csv', sep='|', index_col=0)
#already has an index column in the csv file. Pandas, by default creates its own index. Or you could make the index column the title with: index_col=3. In this example index_col=0
netflix.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  As her father nears the end of his life, filmm...
# 1      s2  ...  After crossing paths at a party, a Cape Town t...
# 2      s3  ...  To protect his family from a powerful drug lor...
# 3      s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4      s5  ...  In a city of coaching centers known to train I...
#
# [5 rows x 12 columns]

# %%
names = ['sumlev', 'region', 'division', 'state', 'name', 'census2010pop', 'estimatebase2010', 'popestimate2010', 'popestimate2011', 'popestimate2012', 'popestimate2013', 'popestimate2014', 'popestimate2015', 'popestimate2016', 'popestimate2017', 'popestimate2018', 'popestimate2019', 'popestimate042020', 'popestimate2020']


nst = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/nst-est2020.csv', names=names)  #header = 0 tells it to ignore the header b/c we're providing our own with names
nst.head()
# Out:
#    sumlev  region  ...  popestimate042020  popestimate2020
# 0  SUMLEV  REGION  ...  POPESTIMATE042020  POPESTIMATE2020
# 1     010       0  ...          329398742        329484123
# 2     020       1  ...           55924275         55849869
# 3     020       2  ...           68357895         68316744
# 4     020       3  ...          126494232        126662754
#
# [5 rows x 19 columns]

# %%
bestsellers = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/bestsellers.csv')

# %%
houses = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/kc_house_data.csv')
houses
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
#df = houses[['bedrooms', 'bathrooms']]

# %%
###set index right in read_csv is the easiest way to do it
df = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/world-happiness-report-2021.csv', index_col='Country name')
df.head(3)
# Out:
#              Regional indicator  ...  Dystopia + residual
# Country name                     ...
# Finland          Western Europe  ...                3.253
# Denmark          Western Europe  ...                2.868
# Switzerland      Western Europe  ...                2.839
#
# [3 rows x 19 columns]

# %%
#You can also request it in dataframe structure
df.loc[["Canada"]]
# Out:
#                  Regional indicator  ...  Dystopia + residual
# Country name                         ...
# Canada        North America and ANZ  ...                2.585
#
# [1 rows x 19 columns]

# %%
#You can also request it in dataframe structure
df.loc[["Canada"]]
# Out:
#                  Regional indicator  ...  Dystopia + residual
# Country name                         ...
# Canada        North America and ANZ  ...                2.585
#
# [1 rows x 19 columns]

# %%
###You can also get a list of countries (the from the ROWS) with .loc, say we want all the North American countries
###

df.loc[['Canada', 'Mexico', 'United States']]
# Out:
#                         Regional indicator  ...  Dystopia + residual
# Country name                                ...
# Canada               North America and ANZ  ...                2.585
# Mexico         Latin America and Caribbean  ...                2.961
# United States        North America and ANZ  ...                2.807
#
# [3 rows x 19 columns]

# %%
#countries.sort_index()  #to sort the index alphabetically

# %%
houses.bedrooms.value_counts().sort_index().plot(kind='bar')

# %%
### .loc helps us view something by row vs by column

df.head(2)
###countries['Albania']   this doesn't work for a row, only for columns
df.loc["Canada"]  ### You get all the info for that one row
# Out:
# Regional indicator                            North America and ANZ
# Ladder score                                                  7.103
# Standard error of ladder score                                0.042
# upperwhisker                                                  7.185
# lowerwhisker                                                  7.021
# Logged GDP per capita                                        10.776
# Social support                                                0.926
# Healthy life expectancy                                        73.8
# Freedom to make life choices                                  0.915
# Generosity                                                    0.089
# Perceptions of corruption                                     0.415
# Ladder score in Dystopia                                       2.43
# Explained by: Log GDP per capita                              1.447
# Explained by: Social support                                  1.044
# ...

# %%
titanic = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/titanic.csv')
titanic.tail()
# Out:
#       pclass  survived                       name  ... boat body  home.dest
# 1304       3         0       Zabour, Miss. Hileni  ...    ?  328          ?
# 1305       3         0      Zabour, Miss. Thamine  ...    ?    ?          ?
# 1306       3         0  Zakarian, Mr. Mapriededer  ...    ?  304          ?
# 1307       3         0        Zakarian, Mr. Ortin  ...    ?    ?          ?
# 1308       3         0         Zimmerman, Mr. Leo  ...    ?    ?          ?
#
# [5 rows x 14 columns]

# %%
#You can also request it in dataframe structure
df.loc[["Canada"]]
# Out:
#                  Regional indicator  ...  Dystopia + residual
# Country name                         ...
# Canada        North America and ANZ  ...                2.585
#
# [1 rows x 19 columns]

# %%
###You can also get a list of countries (the from the ROWS) with .loc, say we want all the North American countries
###

df.loc[['Canada', 'Mexico', 'United States']]
# Out:
#                         Regional indicator  ...  Dystopia + residual
# Country name                                ...
# Canada               North America and ANZ  ...                2.585
# Mexico         Latin America and Caribbean  ...                2.961
# United States        North America and ANZ  ...                2.807
#
# [3 rows x 19 columns]

# %%
###The Titanic df is indexed by number so you'd just pass in the row index 0, 1, 2...

titanic.head(2)
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...    ?                     St Louis, MO
# 1       1         1  ...    ?  Montreal, PQ / Chesterville, ON
#
# [2 rows x 14 columns]

# %%
titanic.loc[7]
# Out:
# pclass                            1
# survived                          0
# name         Andrews, Mr. Thomas Jr
# sex                            male
# age                              39
# sibsp                             0
# parch                             0
# ticket                       112050
# fare                              0
# cabin                           A36
# embarked                          S
# boat                              ?
# body                              ?
# home.dest               Belfast, NI
# Name: 7, dtype: object

# %%
#titanic.loc[[7, 9, 876]]
##You can also use slices

df.loc['Canada': 'Mexico': 2]

##This won't work if Mexico comes before Canada. Would give error
# Out:
#                                     Regional indicator  ...  Dystopia + residual
# Country name                                            ...
# Canada                           North America and ANZ  ...                2.585
# Costa Rica                 Latin America and Caribbean  ...                3.387
# Czech Republic              Central and Eastern Europe  ...                3.124
# Belgium                                 Western Europe  ...                2.862
# Bahrain                   Middle East and North Africa  ...                2.631
# Taiwan Province of China                     East Asia  ...                2.687
# Saudi Arabia              Middle East and North Africa  ...                2.668
# Italy                                   Western Europe  ...                2.794
# Guatemala                  Latin America and Caribbean  ...                3.375
# Singapore                               Southeast Asia  ...                1.379
# ...

# %%
###.iloc also gets the ROW. You just tell it the index location that you want

df.iloc[20]
# Out:
# Regional indicator                            Western Europe
# Ladder score                                            6.69
# Standard error of ladder score                         0.037
# upperwhisker                                           6.762
# lowerwhisker                                           6.618
# Logged GDP per capita                                 10.704
# Social support                                         0.942
# Healthy life expectancy                                 74.0
# Freedom to make life choices                           0.822
# Generosity                                            -0.147
# Perceptions of corruption                              0.571
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.421
# Explained by: Social support                           1.081
# Explained by: Healthy life expectancy                  0.804
# ...

# %%
df.iloc[[20]]   ##double brackets to turn it into a df
# Out:
#              Regional indicator  ...  Dystopia + residual
# Country name                     ...
# France           Western Europe  ...                2.521
#
# [1 rows x 19 columns]

# %%
#You can still use a slice

df.iloc[20:23]
# Out:
#                         Regional indicator  ...  Dystopia + residual
# Country name                                ...
# France                      Western Europe  ...                2.521
# Bahrain       Middle East and North Africa  ...                2.631
# Malta                       Western Europe  ...                2.268
#
# [3 rows x 19 columns]

# %%
###
houses.loc[21612:21618, ['price', 'bedrooms']]   ###After the column we specify which column of info we want for those ROWS
# Out:
#           price  bedrooms
# 21612  325000.0         2

# %%
titanic.loc[50:60:2, ['survived', 'sex']]   ###   ### ###
# Out:
#     survived     sex
# 50         1  female
# 52         0    male
# 54         1    male
# 56         1    male
# 58         0    male
# 60         0    male

# %%
df.loc['Canada': 'France', ['Ladder score']]
# Out:
#                 Ladder score
# Country name
# Canada                 7.103
# Ireland                7.085
# Costa Rica             7.069
# United Kingdom         7.064
# Czech Republic         6.965
# United States          6.951
# Belgium                6.834
# France                 6.690

# %%
df.loc['Canada':'France'][['Ladder score']]  #You can also do it this way
###request the rows first (Canada to France) and then do a lookup/narrow down after the fact ###
# Out:
#                 Ladder score
# Country name
# Canada                 7.103
# Ireland                7.085
# Costa Rica             7.069
# United Kingdom         7.064
# Czech Republic         6.965
# United States          6.951
# Belgium                6.834
# France                 6.690

# %%
###How many people have exactly 33 bedrooms

houses['bedrooms'].value_counts().loc[33]  ### b/c value_counts makes the value the index!!!
# Out:
# 1

# %%
#1 - make the Name the index

pokemon = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/Pokemon.csv', index_col='Name')
pokemon
# Out:
#             Num   Type 1  Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# Name                                     ...
# Bulbasaur     1    Grass  Poison    318  ...       65     45      1      False
# Ivysaur       2    Grass  Poison    405  ...       80     60      2      False
# Venusaur      3    Grass  Poison    525  ...      100     80      3      False
# Charmander    4     Fire     NaN    309  ...       50     65      1      False
# Charmeleon    5     Fire     NaN    405  ...       65     80      2      False
# ...         ...      ...     ...    ...  ...      ...    ...    ...        ...
# Dratini     147   Dragon     NaN    300  ...       50     50      1      False
# Dragonair   148   Dragon     NaN    420  ...       70     70      2      False
# Dragonite   149   Dragon  Flying    600  ...      100     80      3      False
# Mewtwo      150  Psychic     NaN    680  ...       90    130      1       True
# ...

# %%
#Sort by the attack column

pokemon.sort_values('Attack', ascending=False, inplace=True)  #ascending=False to go fro highest to lowest

# %%
#Sort the pokemon from the Num column, from lowest to highest, in place.

pokemon.sort_values('Num', inplace=True)
pokemon
# Out:
#             Num   Type 1  Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# Name                                     ...
# Bulbasaur     1    Grass  Poison    318  ...       65     45      1      False
# Ivysaur       2    Grass  Poison    405  ...       80     60      2      False
# Venusaur      3    Grass  Poison    525  ...      100     80      3      False
# Charmander    4     Fire     NaN    309  ...       50     65      1      False
# Charmeleon    5     Fire     NaN    405  ...       65     80      2      False
# ...         ...      ...     ...    ...  ...      ...    ...    ...        ...
# Dratini     147   Dragon     NaN    300  ...       50     50      1      False
# Dragonair   148   Dragon     NaN    420  ...       70     70      2      False
# Dragonite   149   Dragon  Flying    600  ...      100     80      3      False
# Mewtwo      150  Psychic     NaN    680  ...       90    130      1       True
# ...

# %%
#Sort the pokemon by the Total column AND the Attack column in that order not acending (not 0, 1, 2, 3...)

pokemon.sort_values(['Total','Attack'], ascending=False)  #
# Out:
#            Num    Type 1  Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# Name                                     ...
# Mewtwo     150   Psychic     NaN    680  ...       90    130      1       True
# Dragonite  149    Dragon  Flying    600  ...      100     80      3      False
# Mew        151   Psychic     NaN    600  ...      100    100      1      False
# Moltres    146      Fire  Flying    580  ...       85     90      1       True
# Zapdos     145  Electric  Flying    580  ...       90    100      1       True
# ...        ...       ...     ...    ...  ...      ...    ...    ...        ...
# Kakuna      14       Bug  Poison    205  ...       25     35      2      False
# Metapod     11       Bug     NaN    205  ...       25     30      2      False
# Magikarp   129     Water     NaN    200  ...       20     80      1      False
# Weedle      13       Bug  Poison    195  ...       20     50      1      False
# ...

# %%
#Sort the index (which is currently their name) from A-Z

pokemon.sort_index()
# Out:
#             Num    Type 1  Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# Name                                      ...
# Abra         63   Psychic     NaN    310  ...       55     90      1      False
# Aerodactyl  142      Rock  Flying    515  ...       75    130      1      False
# Alakazam     65   Psychic     NaN    500  ...       95    120      3      False
# Arbok        24    Poison     NaN    438  ...       79     80      2      False
# Arcanine     59      Fire     NaN    555  ...       80     95      2      False
# ...         ...       ...     ...    ...  ...      ...    ...    ...        ...
# Weepinbell   70     Grass  Poison    390  ...       45     55      2      False
# Weezing     110    Poison     NaN    490  ...       70     60      2      False
# Wigglytuff   40    Normal   Fairy    435  ...       50     45      2      False
# Zapdos      145  Electric  Flying    580  ...       90    100      1       True
# ...

# %%
### Find the average Speed of the 10 pokemon with the highest Speed.

pokemon['Speed'].nlargest(10).mean()   ###Do .mean on the 10 largest
# Out:
# 122.0

# %%
#Of the top 20 pokemon witht he highest Attack values, what is the most common value for 'Type 1'
pokemon.sort_values('Attack').tail(20)['Type 1'].mode()
# Out:
# 0    Fighting
# dtype: object

# %%
###These challenges use .loc and .iloc
#Retrieve the row with the index label of 'Diglett'

pokemon.loc['Diglett']   #.loc to retrieve the row
# Out:
# Num              50
# Type 1       Ground
# Type 2          NaN
# Total           265
# HP               10
# Attack           55
# Defense          25
# Sp. Atk          35
# Sp. Def          45
# Speed            95
# Stage             1
# Legendary     False
# Name: Diglett, dtype: object

# %%
#Retrieve the rows for the two fox-like Pokemon: Eevee and Vulpix

pokemon.loc[['Eevee', 'Vulpix']]
# Out:
#         Num  Type 1 Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# Name                               ...
# Eevee   133  Normal    NaN    325  ...       65     55      1      False
# Vulpix   37    Fire    NaN    299  ...       65     65      1      False
#
# [2 rows x 12 columns]

# %%
#Make sure your DF is sorted by index (A-Z). Retrieve the rows from Charzard to Charmeleon.

pokemon.loc['Charizard':'Caterpie']
# Out:
#            Num Type 1  Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# Name                                  ...
# Charizard    6   Fire  Flying    534  ...       85    100      3      False
# Squirtle     7  Water     NaN    314  ...       64     43      1      False
# Wartortle    8  Water     NaN    405  ...       80     58      2      False
# Blastoise    9  Water     NaN    530  ...      105     78      3      False
# Caterpie    10    Bug     NaN    195  ...       20     45      1      False
#
# [5 rows x 12 columns]

# %%
#Retrive the 30th, 40th, and 50th rows by position
###if you do .loc you'll notice that there's nothing with the index label of 30, 40 or 50. 
#we want the items in those index positions!

pokemon.iloc[[30, 40, 50]]  #iloc = by position. 
#pokemon.iloc[30:50, 2]
# Out:
#            Num  Type 1  Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# Name                                   ...
# Nidoqueen   31  Poison  Ground    505  ...       85     76      3      False
# Zubat       41  Poison  Flying    245  ...       40     55      1      False
# Dugtrio     51  Ground     NaN    405  ...       70    120      2      False
#
# [3 rows x 12 columns]

# %% [markdown]
# Filtering data

# %%
#Looking at the titanic dataset...how could you get all the people who are older than 20?
#                              ...how could you get all the people of gender female AND they survived

# %%
#Or with the houses dataset, how could we get all the homes that are less than 1M
#or waterfront and >$5M

# %%
df = titanic.head()
df
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...    ?                     St Louis, MO
# 1       1         1  ...    ?  Montreal, PQ / Chesterville, ON
# 2       1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 3       1         0  ...  135  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    ?  Montreal, PQ / Chesterville, ON
#
# [5 rows x 14 columns]

# %%
df.sex
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
df.sex == 'female'    #gives you a boolean value
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
###We can then pass this series into the df to get the info for these rows

df[df.sex == 'female']
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...    ?                     St Louis, MO
# 2       1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    ?  Montreal, PQ / Chesterville, ON
#
# [3 rows x 14 columns]

# %%
###Using this logic, how can you find the rows where survived is set to 0? - meaning they died

df['survived'] == 0   ### plug this logic into the dataframe itself ###
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: survived, dtype: bool

# %%
df[df.survived==0]
# Out:
#    pclass  survived  ... body                        home.dest
# 2       1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 3       1         0  ...  135  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    ?  Montreal, PQ / Chesterville, ON
#
# [3 rows x 14 columns]

# %%
###Find all of the passangers who survived. Survived usually EQUALS 1

titanic['survived'] == 1
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: survived, Length: 1309, dtype: bool

# %%
titanic[titanic['survived']==1]#.count
# Out:
#       pclass  survived  ... body                        home.dest
# 0          1         1  ...    ?                     St Louis, MO
# 1          1         1  ...    ?  Montreal, PQ / Chesterville, ON
# 5          1         1  ...    ?                     New York, NY
# 6          1         1  ...    ?                       Hudson, NY
# 8          1         1  ...    ?              Bayside, Queens, NY
# ...      ...       ...  ...  ...                              ...
# 1261       3         1  ...    ?                                ?
# 1277       3         1  ...    ?                                ?
# 1286       3         1  ...    ?                                ?
# 1290       3         1  ...    ?                                ?
# 1300       3         1  ...    ?                                ?
#
# [500 rows x 14 columns]

# %%
###but if we check say the age column where age == 18, that gives us a problem (shows no results)

titanic['age'] == 18
titanic[titanic['age']==18]  ###shows no results b/c the type is wrong. There are some '?' marks in the age column
                                          ###python will consider all the numbers in that column as 'strings' instead of ints, so there will be no results
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
#You can fix it with: 
titanic[titanic['age']== '18'].head(3)   ###A better way is to cast it
# Out:
#      pclass  survived  ... body      home.dest
# 11        1         1  ...    ?   New York, NY
# 198       1         1  ...    ?   New York, NY
# 228       1         0  ...    ?  Madrid, Spain
#
# [3 rows x 14 columns]

# %%
###Start at 2:45: https://www.udemy.com/course/python-data-analysis-visualization/learn/lecture/29490052#overview

# %%
### ###

titanic.pclass != 1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304     True
# 1305     True
# 1306     True
# 1307     True
# 1308     True
# Name: pclass, Length: 1309, dtype: bool

# %%
### ###

titanic[titanic['pclass'] != 1]
titanic[titanic['pclass'] != 1]#['pclass'].value_counts()   ####  Why is the second pclass necessary?
# Out:
#       pclass  survived  ... body                                 home.dest
# 323        2         0  ...    ?                       Russia New York, NY
# 324        2         1  ...    ?                       Russia New York, NY
# 325        2         0  ...    ?                        Bryn Mawr, PA, USA
# 326        2         0  ...    ?  Buenos Aires, Argentina / New Jersey, NJ
# 327        2         0  ...    ?            Cornwall, England Houghton, MI
# ...      ...       ...  ...  ...                                       ...
# 1304       3         0  ...  328                                         ?
# 1305       3         0  ...    ?                                         ?
# 1306       3         0  ...  304                                         ?
# 1307       3         0  ...    ?                                         ?
# 1308       3         0  ...    ?                                         ?
#
# [986 rows x 14 columns]

# %%
###Then we can even plot this
                              ###If you don't give it the second place, then it will give you a bar chart for all the columns where pclass != 1 
titanic[titanic['pclass'] != 1].pclass.value_counts().plot(kind='bar')

# %%
#titanic[titanic['pclass'] != 1].value_counts()

# %%
###How can you get all the house prices where the value is > 5M

houses['price'] > 5000000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: price, Length: 21613, dtype: bool

# %%
###

houses[houses['price'] > 5000000].price.plot(kind='bar')

# %%
houses.sqft_living < 2000
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 21608     True
# 21609    False
# 21610     True
# 21611     True
# 21612     True
# Name: sqft_living, Length: 21613, dtype: bool

# %%
houses[houses.sqft_living < 2000].sqft_living.value_counts().plot(kind='pie')

# %%
### houses.sqft_living < 2000   this info gives you a series and then you can plug this info into the df and it will give you a df with that specific info

# %%
###

houses['bedrooms'].between(5, 7)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: bedrooms, Length: 21613, dtype: bool

# %%
houses[houses['bedrooms'].between(5, 7)].bedrooms.value_counts().plot(kind='bar')

# %%
countries = ['India', 'Japan', 'South Korea']

netflix['country'] #take this 'country series
#and check if they're in our countries list

netflix['country'].isin(countries)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806     True
# Name: country, Length: 8807, dtype: bool

# %%
###  ###

netflix[netflix['country'].isin(countries)].country.value_counts().plot(kind='pie')

# %%
mature = netflix['rating'].isin(['TV-MA', 'R'])

# %%
netflix[mature].rating.value_counts().plot(kind='pie')

# %%
titanic.sex == 'female'
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %%
###Using and and &

women = titanic.sex == 'female'

died = titanic.survived == 0

#women & died   Both have to be true

# %%
titanic[women & died]
# Out:
#       pclass  survived  ... body                        home.dest
# 2          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 4          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 105        1         0  ...    ?                     New York, NY
# 169        1         0  ...    ?       Paris, France New York, NY
# 286        1         0  ...    ?                     New York, NY
# ...      ...       ...  ...  ...                              ...
# 1273       3         0  ...    ?                                ?
# 1276       3         0  ...    ?                                ?
# 1279       3         0  ...    ?                                ?
# 1304       3         0  ...  328                                ?
# 1305       3         0  ...    ?                                ?
#
# [127 rows x 14 columns]

# %%
#If you do it this way, then you need parenthesis
titanic[(titanic.sex == 'female') & (titanic.survived == 0)]
# Out:
#       pclass  survived  ... body                        home.dest
# 2          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 4          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 105        1         0  ...    ?                     New York, NY
# 169        1         0  ...    ?       Paris, France New York, NY
# 286        1         0  ...    ?                     New York, NY
# ...      ...       ...  ...  ...                              ...
# 1273       3         0  ...    ?                                ?
# 1276       3         0  ...    ?                                ?
# 1279       3         0  ...    ?                                ?
# 1304       3         0  ...  328                                ?
# 1305       3         0  ...    ?                                ?
#
# [127 rows x 14 columns]

# %%
titanic[women & died]
# Out:
#       pclass  survived  ... body                        home.dest
# 2          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 4          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 105        1         0  ...    ?                     New York, NY
# 169        1         0  ...    ?       Paris, France New York, NY
# 286        1         0  ...    ?                     New York, NY
# ...      ...       ...  ...  ...                              ...
# 1273       3         0  ...    ?                                ?
# 1276       3         0  ...    ?                                ?
# 1279       3         0  ...    ?                                ?
# 1304       3         0  ...  328                                ?
# 1305       3         0  ...    ?                                ?
#
# [127 rows x 14 columns]

# %%
#titanic[(titanic.sex == 'female') & (titanic.survived == 0)]

#houses.view == 4 
#houses.grade >= 10

houses[(houses.view == 4) & (houses.grade >= 10)]  ###originally forgot the second parens
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 300    3225069065  20140624T000000  ...           4550       19508
# 312    1860600135  20140502T000000  ...           2880        5400
# 409    1560930070  20140911T000000  ...           3180       36852
# 540     622049114  20150218T000000  ...           3980      104374
# 757    9273200140  20150121T000000  ...           3220        4500
# ...           ...              ...  ...            ...         ...
# 20767  8043700105  20150417T000000  ...           2670        8525
# 20923  7852070210  20140527T000000  ...           4240       12813
# 21050  2424059170  20150219T000000  ...           3440       36859
# 21201   518500460  20141008T000000  ...           3560        5762
# 21576  9253900271  20150107T000000  ...           3470       18270
#
# [125 rows x 21 columns]

# %%
good_view = houses['view'] ==4
high_grade = houses['grade'] >= 10

# %%
houses[good_view & high_grade]
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 300    3225069065  20140624T000000  ...           4550       19508
# 312    1860600135  20140502T000000  ...           2880        5400
# 409    1560930070  20140911T000000  ...           3180       36852
# 540     622049114  20150218T000000  ...           3980      104374
# 757    9273200140  20150121T000000  ...           3220        4500
# ...           ...              ...  ...            ...         ...
# 20767  8043700105  20150417T000000  ...           2670        8525
# 20923  7852070210  20140527T000000  ...           4240       12813
# 21050  2424059170  20150219T000000  ...           3440       36859
# 21201   518500460  20141008T000000  ...           3560        5762
# 21576  9253900271  20150107T000000  ...           3470       18270
#
# [125 rows x 21 columns]

# %%
high_quality = houses['grade'] > 10
good_view = houses['view'] == 4
small = houses['sqft_living'] <= 3200

# %%
houses[high_quality & good_view & small]
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 4013    724069059  20140509T000000  ...           3000       15959
# 8568   8653600100  20150330T000000  ...           3390       17003
# 16837  4441300170  20150112T000000  ...           3110       11570
#
# [3 rows x 21 columns]

# %%
houses[(houses.view == 4) & (houses.grade >= 10) & (houses.sqft_living <= 3200)]
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 409    1560930070  20140911T000000  ...           3180       36852
# 1420   8073000550  20150415T000000  ...           2290       13496
# 2179   3343301920  20150302T000000  ...           2940        8890
# 4013    724069059  20140509T000000  ...           3000       15959
# 4220   3342104046  20140708T000000  ...           2870       11151
# 4339   3760500336  20141126T000000  ...           2750       13496
# 4408   5154200015  20150414T000000  ...           2580       12119
# 5666   9253900417  20150128T000000  ...           2850       18782
# 5827   9829200250  20150105T000000  ...           2670        6270
# 7203   2927600630  20150416T000000  ...           2724       10634
# 8568   8653600100  20150330T000000  ...           3390       17003
# 8784   3343302110  20150306T000000  ...           3140       11949
# 9935   2818100060  20140520T000000  ...           2810        8087
# ...

# %%
recent_houses = houses[(houses['yr_built'] >= 2014) | (houses['yr_renovated'] > 2012)]   ###The key here it to keep them in parens so that it knows what to compare
                                                                         ## | == or

recent_houses.sort_values('yr_renovated')
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 42     7203220400  20140707T000000  ...           3625        5639
# 20504   301401390  20140805T000000  ...           2166        4000
# 20509  7889601270  20140821T000000  ...           1470        6000
# 20511  9828701508  20140520T000000  ...           1630        3136
# 20520  1926059236  20141010T000000  ...           2950        5981
# ...           ...              ...  ...            ...         ...
# 5683   2202500255  20150305T000000  ...           1690        9737
# 4240   6071800100  20150327T000000  ...           1920       13452
# 16683  5113000420  20150320T000000  ...           1690       20000
# 3156   6821100195  20150331T000000  ...           1400        6000
# 7417   8665900328  20150123T000000  ...           1900       12868
#
# [741 rows x 21 columns]

# %%
fincher = netflix['director'] == 'David Fincher'
scorsese = netflix['director'] == 'Martin Scorsese'
recent = netflix['release_year'] > 2015

netflix[fincher | scorsese & recent]   ###This uses | and &
###It does seem much more readable when you save them in variables
### But this gives the wrong answer b/c you still need to group them correctly ###

#netflix[(fincher | scorsese) & recent]
# Out:
#      show_id  ...                                        description
# 600     s601  ...  An aloof investment banker's life spirals into...
# 1595   s1596  ...  1930s Hollywood is reevaluated through the eye...
# 3227   s3228  ...  Hit man Frank Sheeran looks back at the secret...
# 3759   s3760  ...  In an alchemic mix of fact and fantasy, Martin...
# 7701   s7702  ...  A woman and her daughter are caught in a game ...
# 8320   s8321  ...  When a young computer hacker is tasked with in...
# 8511   s8512  ...  Director David Fincher's biographical drama ch...
# 8802   s8803  ...  A political cartoonist, a crime reporter and a...
#
# [8 rows x 12 columns]

# %%
netflix[(fincher | scorsese) & recent]   ###It can get either 'fincher or scorsese
                                          #and it must be recent
# Out:
#      show_id  ...                                        description
# 1595   s1596  ...  1930s Hollywood is reevaluated through the eye...
# 3227   s3228  ...  Hit man Frank Sheeran looks back at the secret...
# 3759   s3760  ...  In an alchemic mix of fact and fantasy, Martin...
#
# [3 rows x 12 columns]

# %% [markdown]
# New topic - isna()

# %%
#if you want to find each of the netflix 'director' columns that are missing values then...

netflix['director'].isna()
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 8802    False
# 8803     True
# 8804    False
# 8805    False
# 8806    False
# Name: director, Length: 8807, dtype: bool

# %%
#Then we can pass the above into netflix:

netflix[netflix['director'].isna()]
# Out:
#      show_id  ...                                        description
# 1         s2  ...  After crossing paths at a party, a Cape Town t...
# 3         s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4         s5  ...  In a city of coaching centers known to train I...
# 10       s11  ...  Sicily boasts a bold "Anti-Mafia" coalition. B...
# 14       s15  ...  Cameras following Bengaluru police on the job ...
# ...      ...  ...                                                ...
# 8795   s8796  ...  Now that he's discovered the Pendulum Summonin...
# 8796   s8797  ...  During the Mongol invasions, Yunus Emre leaves...
# 8797   s8798  ...  Teen surfer Zak Storm is mysteriously transpor...
# 8800   s8801  ...  Strong-willed, middle-class Kashaf and carefre...
# 8803   s8804  ...  While living alone in a spooky town, a young g...
#
# [2634 rows x 12 columns]

# %%
netflix[netflix['director'].isna() & netflix['cast'].isna()]

###interesting that you don't need parens here
# Out:
#      show_id  ...                                        description
# 3         s4  ...  Feuds, flirtations and toilet talk go down amo...
# 10       s11  ...  Sicily boasts a bold "Anti-Mafia" coalition. B...
# 14       s15  ...  Cameras following Bengaluru police on the job ...
# 66       s67  ...  Explore the history and flavors of regional In...
# 69       s70  ...  The writings of Nobel Prize winner Rabindranat...
# ...      ...  ...                                                ...
# 8605   s8606  ...  Social media star Hayes Grier returns to North...
# 8609   s8610  ...  Australia's toughest tow truck operators work ...
# 8700   s8701  ...  Part live-action and part animation, this visu...
# 8755   s8756  ...  This reality series recounts true stories of w...
# 8803   s8804  ...  While living alone in a spooky town, a young g...
#
# [352 rows x 12 columns]

# %%
houses[houses['price'] > 3000000].zipcode.value_counts().plot(kind='bar')

# %%
houses.zipcode.value_counts().head(10).plot(kind='bar')  #without the .head(10) there will be too many to show

# %%
btc = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/coin_Bitcoin.csv')
btc.head(2)
# Out:
#    SNo     Name Symbol  ...       Close  Volume     Marketcap
# 0    1  Bitcoin    BTC  ...  144.539993     0.0  1.603769e+09
# 1    2  Bitcoin    BTC  ...  139.000000     0.0  1.542813e+09
#
# [2 rows x 10 columns]

# %%
#Remember that row is 0 and column is 1

btc.drop(labels='Symbol', axis=1)
# Out:
#        SNo     Name  ...        Volume     Marketcap
# 0        1  Bitcoin  ...  0.000000e+00  1.603769e+09
# 1        2  Bitcoin  ...  0.000000e+00  1.542813e+09
# 2        3  Bitcoin  ...  0.000000e+00  1.298955e+09
# 3        4  Bitcoin  ...  0.000000e+00  1.168517e+09
# 4        5  Bitcoin  ...  0.000000e+00  1.085995e+09
# ...    ...      ...  ...           ...           ...
# 2986  2987  Bitcoin  ...  3.872897e+10  6.354508e+11
# 2987  2988  Bitcoin  ...  2.438396e+10  6.499397e+11
# 2988  2989  Bitcoin  ...  2.492431e+10  6.615748e+11
# 2989  2990  Bitcoin  ...  2.672155e+10  6.326962e+11
# 2990  2991  Bitcoin  ...  2.650126e+10  6.418992e+11
#
# [2991 rows x 9 columns]

# %%
btc.drop(labels=['Name', 'Symbol', 'Open'], axis=1).head(1)
# Out:
#    SNo                 Date        High  ...       Close  Volume     Marketcap
# 0    1  2013-04-29 23:59:59  147.488007  ...  144.539993     0.0  1.603769e+09
#
# [1 rows x 7 columns]

# %%
### This is actually an easier-to-understand way to do it

btc.drop(columns=['Name', 'Open', 'Close']).head(1)

### columns= replaces 'labels' AND axis
# Out:
#    SNo Symbol                 Date        High    Low  Volume     Marketcap
# 0    1    BTC  2013-04-29 23:59:59  147.488007  134.0     0.0  1.603769e+09

# %%
### How to get a column out is the same as how to create a new column

titanic['sex']  ### get a column out
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
titanic['species'] = 'human'   ###Put a column in ###
titanic.head(2)
# Out:
#    pclass  survived  ...                        home.dest species
# 0       1         1  ...                     St Louis, MO   human
# 1       1         1  ...  Montreal, PQ / Chesterville, ON   human
#
# [2 rows x 15 columns]

# %%
###This way also works and allows you to specify the location

#houses.insert(0, 'county', 'King County')

# %%
houses
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
#You can also insert a duplicate

houses['sale_price'] = houses['price']  #Now our new column's values are equal to our price column values
houses.head(2)
# Out:
#            id             date     price  ...  sqft_living15  sqft_lot15  sale_price
# 0  7129300520  20141013T000000  221900.0  ...           1340        5650    221900.0
# 1  6414100192  20141209T000000  538000.0  ...           1690        7639    538000.0
#
# [2 rows x 22 columns]

# %%
titanic.head(2)
# Out:
#    pclass  survived  ...                        home.dest species
# 0       1         1  ...                     St Louis, MO   human
# 1       1         1  ...  Montreal, PQ / Chesterville, ON   human
#
# [2 rows x 15 columns]

# %%
###Let's dynamically calculate a column that's the combination of sibsp	parch
#We'll call it family_members

titanic['sibsp'] + titanic['parch']
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Length: 1309, dtype: int64

# %%
titanic['family_members'] = titanic['sibsp'] + titanic['parch']
titanic.head(2)
# Out:
#    pclass  survived  ... species family_members
# 0       1         1  ...   human              0
# 1       1         1  ...   human              3
#
# [2 rows x 16 columns]

# %%
titanic[titanic['survived'] == 1].sort_values('family_members', ascending=False).head(2)
# Out:
#      pclass  survived  ... species family_members
# 641       3         1  ...   human              6
# 625       3         1  ...   human              6
#
# [2 rows x 16 columns]

# %%
#Challenge: Get the price per square foot of house sold

houses['price_sqft'] = houses['price'] / houses['sqft_living']

# %%
###Let's then sort by the highest price per square foot

houses.sort_values('price_sqft', ascending=False).head()
# Out:
#                id             date  ...  sale_price  price_sqft
# 19336  6021500970  20150407T000000  ...    874950.0  810.138889
# 4013    724069059  20140509T000000  ...   2400000.0  800.000000
# 10446  1118000320  20150508T000000  ...   3400000.0  798.122066
# 8623   6303400395  20150130T000000  ...    325000.0  792.682927
# 9314   4389200610  20141201T000000  ...    903000.0  792.105263
#
# [5 rows x 23 columns]

# %%
###Start here

btc.set_index('Date').head(2)  #Remember to set the index to 'Date' before we do Close - Open
# Out:
#                      SNo     Name Symbol  ...       Close  Volume     Marketcap
# Date                                      ...
# 2013-04-29 23:59:59    1  Bitcoin    BTC  ...  144.539993     0.0  1.603769e+09
# 2013-04-30 23:59:59    2  Bitcoin    BTC  ...  139.000000     0.0  1.542813e+09
#
# [2 rows x 9 columns]

# %%
btc['Close'] - btc['Open']
# Out:
# 0         10.095993
# 1         -5.000000
# 2        -22.010002
# 3        -11.169998
# 4         -8.500000
#            ...
# 2986     347.448412
# 2987     814.127040
# 2988     622.214900
# 2989   -1538.341974
# 2990     511.683796
# Length: 2991, dtype: float64

# %%
btc['change'] = btc['Close'] - btc['Open']
btc.sort_values('change', ascending=False).head(2)
# Out:
#        SNo     Name Symbol  ...        Volume     Marketcap       change
# 2842  2843  Bitcoin    BTC  ...  1.014672e+11  8.603427e+11  7309.636429
# 2919  2920  Bitcoin    BTC  ...  5.828404e+10  1.009780e+12  4943.962424
#
# [2 rows x 11 columns]

# %%
btc['delta'] = btc['High'] - btc['Low']

# %%
btc.sort_values('delta', ascending=False).head(2)   ###You pass whatever you want to sort by into sort_values()
# Out:
#        SNo     Name Symbol  ...     Marketcap       change         delta
# 2942  2943  Bitcoin    BTC  ...  6.924526e+11 -5942.534981  12864.619573
# 2857  2858  Bitcoin    BTC  ...  9.099259e+11 -5380.502887   8914.339488
#
# [2 rows x 12 columns]

# %%
###How can you use the above code to look at just the 'delta' column?

btc.sort_values('delta', ascending=False).head(5)['delta'].sort_values().plot(kind='bar');

# %%
#The x-axis is the index here...We should change that

# %%
#btc = btc.set_index('Date', inplace=True)
#### AttributeError: 'NoneType' object has no attribute 'set_index'
#### Frequent NoneType errors :/
#btc.sort_values('delta', ascending=False).head(5)['delta'].plot(kind='bar')

# %%
###Modifying DFs continues - renaming

# %%
countries = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/countries of the world.csv')
countries.head(2)
# Out:
#         Country                               Region  ...  Industry  Service
# 0  Afghanistan         ASIA (EX. NEAR EAST)           ...      0,24     0,38
# 1      Albania   EASTERN EUROPE                       ...     0,188    0,579
#
# [2 rows x 20 columns]

# %%
#The column names here are kind of hard to read...There are commas, :, lots of spaces...

mapper = {'Regional indicator': 'regional_indicator', 'Ladder Score': 'ladder_score'}

countries.rename(columns=mapper).head(2)   ###Should actually be working with the world_happiness dataset


###You can easily rename rows by doing
#index = mapper
#vs
#columns= mapper
# Out:
#         Country                               Region  ...  Industry  Service
# 0  Afghanistan         ASIA (EX. NEAR EAST)           ...      0,24     0,38
# 1      Albania   EASTERN EUROPE                       ...     0,188    0,579
#
# [2 rows x 20 columns]

# %%
### .loc works well when you reset the index_col to something other than a number
###So if you reset the countries index to a country, then you can easily access that country with
###   .loc['Spain']

# %%
### ###
countries = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/world-happiness-report-2021.csv', index_col='Country name')
countries.head(2)
# Out:
#              Regional indicator  ...  Dystopia + residual
# Country name                     ...
# Finland          Western Europe  ...                3.253
# Denmark          Western Europe  ...                2.868
#
# [2 rows x 19 columns]

# %%
###Then it's very easy to access a specific country

countries.loc['France']    #This gives you a series back b/c I only asked for a single row
# Out:
# Regional indicator                            Western Europe
# Ladder score                                            6.69
# Standard error of ladder score                         0.037
# upperwhisker                                           6.762
# lowerwhisker                                           6.618
# Logged GDP per capita                                 10.704
# Social support                                         0.942
# Healthy life expectancy                                 74.0
# Freedom to make life choices                           0.822
# Generosity                                            -0.147
# Perceptions of corruption                              0.571
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.421
# Explained by: Social support                           1.081
# Explained by: Healthy life expectancy                  0.804
# ...

# %%
countries.loc[['France']]
# Out:
#              Regional indicator  ...  Dystopia + residual
# Country name                     ...
# France           Western Europe  ...                2.521
#
# [1 rows x 19 columns]

# %%
#countries.loc['Brazil': 'Cambodia']   #This will give you a df

# %%
###How can you get the row for Brazil and just the 'Ladder score' for the column?

countries.loc['Brazil', ['Ladder score']]   #You can pass in a list to either the row or columns
# Out:
# Ladder score    6.33
# Name: Brazil, dtype: object

# %%
###

countries.loc[['Brazil', 'France'], ['Ladder score', 'Social support']]
# Out:
#               Ladder score  Social support
# Country name
# Brazil                6.33           0.882
# France                6.69           0.942

# %%
#How can you use .loc to change info

#Imagine you want to change ['Regional indication'] for these three countries 'Denmark', 'Sweden', 'Norway' to be more specific

countries.loc[['Denmark', 'Sweden', 'Norway']]
# Out:
#              Regional indicator  ...  Dystopia + residual
# Country name                     ...
# Denmark          Western Europe  ...                2.868
# Sweden           Western Europe  ...                2.683
# Norway           Western Europe  ...                2.580
#
# [3 rows x 19 columns]

# %%
countries.loc[['Denmark', 'Sweden', 'Norway'], 'Regional indicator'] = 'Scandinavia'

countries    #Incredible!
# Out:
#               Regional indicator  ...  Dystopia + residual
# Country name                      ...
# Finland           Western Europe  ...                3.253
# Denmark              Scandinavia  ...                2.868
# Switzerland       Western Europe  ...                2.839
# Iceland           Western Europe  ...                2.967
# Netherlands       Western Europe  ...                2.798
# ...                          ...  ...                  ...
# Lesotho       Sub-Saharan Africa  ...                1.800
# Botswana      Sub-Saharan Africa  ...                0.648
# Rwanda        Sub-Saharan Africa  ...                1.095
# Zimbabwe      Sub-Saharan Africa  ...                1.205
# Afghanistan           South Asia  ...                1.895
#
# [149 rows x 19 columns]

# %%
###It's easier to do the above with .replace b/c .replace is semantically meaningful

# %%
###You can also set a column and create a new column in the same .loc such as:

countries.loc[['Finland', 'Sweden', 'Norway'], ['Regional indicator, isCold']] = 'Dogs!'

### The above line sets the 'Regional indicator column to 'Dogs' and creates an 'isCold' column and also sets it to Dogs!
countries.head(5)

#### Something is wrong with the above line. It isn't resetting 'Regional indicator' ####
# Out:
#              Regional indicator  ...  Regional indicator, isCold
# Country name                     ...
# Finland          Western Europe  ...                       Dogs!
# Denmark             Scandinavia  ...                         NaN
# Switzerland      Western Europe  ...                         NaN
# Iceland          Western Europe  ...                         NaN
# Netherlands      Western Europe  ...                         NaN
#
# [5 rows x 20 columns]

# %%
###One more common use of .loc ###

many_bedrooms = houses['bedrooms'] = 3


#### I think that I already changed/saved >= 4 (changed back to 10) to Too Many! so now it's a string.
####How can I fix this?
###we can pass this boolean mask to .loc  to update only that column

# %%
#houses[many_bedrooms]
#houses.loc[many_bedrooms]  #This gives us the same

# %%
#You can also get those rows and specific columns

houses.loc[many_bedrooms, ['bedrooms', 'bathrooms']]
# Out:
# bedrooms       3
# bathrooms    3.0
# Name: 3, dtype: object

# %%
###You can also use this mask to reset a specific column for those rows

houses.loc[many_bedrooms, 'bedrooms'] = 3
houses.tail(20)
# Out:
#                id             date  ...  sale_price  price_sqft
# 21593  8672200110  20150317T000000  ...   1088000.0  260.911271
# 21594  5087900040  20141017T000000  ...    350000.0  140.000000
# 21595  1972201967  20141031T000000  ...    520000.0  339.869281
# 21596  7502800100  20140813T000000  ...    679950.0  188.875000
# 21597   191100405  20150421T000000  ...   1575000.0  461.876833
# 21598  8956200760  20141013T000000  ...    541800.0  173.765234
# 21599  7202300110  20140915T000000  ...    810000.0  203.007519
# 21600   249000205  20141015T000000  ...   1537000.0  343.847875
# 21601  5100403806  20150407T000000  ...    467000.0  327.719298
# 21602   844000965  20140626T000000  ...    224000.0  149.333333
# 21603  7852140040  20140825T000000  ...    507250.0  223.458150
# 21604  9834201367  20150126T000000  ...    429000.0  287.919463
# 21605  3448900210  20141014T000000  ...    610685.0  242.335317
# 21606  7936000429  20150326T000000  ...   1007500.0  287.037037
# ...

# %%
#start at ~6: https://www.udemy.com/course/python-data-analysis-visualization/learn/lecture/29493332#overview

# %%
#One more example

#Take the high grade homes
high_quality = houses['grade'] > 12
#and the hhomes that are waterfront
great_views = houses['view'] == 4

houses[great_views]
# Out:
#                id             date  ...  sale_price  price_sqft
# 21     2524049179  20140826T000000  ...   2000000.0  655.737705
# 58     7922800400  20140827T000000  ...    951000.0  292.615385
# 230    8096000060  20150413T000000  ...    655000.0  451.724138
# 246    2025069065  20140929T000000  ...   2400000.0  657.534247
# 264    2123039032  20141027T000000  ...    369900.0  486.710526
# ...           ...              ...  ...         ...         ...
# 20767  8043700105  20150417T000000  ...   2300000.0  527.522936
# 20923  7852070210  20140527T000000  ...   1149000.0  193.434343
# 21050  2424059170  20150219T000000  ...    900000.0  126.404494
# 21201   518500460  20141008T000000  ...   2230000.0  593.085106
# 21576  9253900271  20150107T000000  ...   3567000.0  735.463918
#
# [319 rows x 23 columns]

# %%
houses[great_views & high_quality]
# Out:
#                id             date  ...  sale_price  price_sqft
# 9254   9208900037  20140919T000000  ...   6885000.0  696.157735
# 14556  2303900035  20140611T000000  ...   2888000.0  333.102653
# 19017  2303900100  20140911T000000  ...   3800000.0  689.655172
#
# [3 rows x 23 columns]

# %%
houses.loc[high_quality & great_views, ['luxury_level']] = 'ultra'
houses.head(3)
# Out:
#            id             date     price  ...  sale_price  price_sqft  luxury_level
# 0  7129300520  20141013T000000  221900.0  ...    221900.0  188.050847           NaN
# 1  6414100192  20141209T000000  538000.0  ...    538000.0  209.338521           NaN
# 2  5631500400  20150225T000000  180000.0  ...    180000.0  233.766234           NaN
#
# [3 rows x 24 columns]

# %% [markdown]
# How To Deal with N/As

# %%
###Why are most of the titanic columns objects?
#b/c most of the columns, such as 'age' has some question marks in them

# %%
titanic.age.value_counts()
# Out:
# ?         263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
###if we want to convert those numbers to floats (to preserve dates like the infant at 0.945), then we first have to deal with those question marks
#titanic['age'].astype('float')  ##ValueError: could not convert string to float: '?'

# %%
#We can get rid of the '?'s with .replace

titanic['age'].replace(['?'], [None], inplace=True)

# %%
titanic.age.value_counts(dropna=False)
# Out:
# NaN       263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
###We can convert NaN to float so:

titanic.age.astype('float')
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
titanic['age_float'] = titanic['age'].astype('float')   ###Do this line to save our 'float age' column in the df
titanic.head()
# Out:
#    pclass  survived  ... family_members age_float
# 0       1         1  ...              0   29.0000
# 1       1         1  ...              3    0.9167
# 2       1         0  ...              3    2.0000
# 3       1         0  ...              3   30.0000
# 4       1         0  ...              3   25.0000
#
# [5 rows x 17 columns]

# %%
titanic = titanic['age'].astype('float')

# %%
titanic.head()
# Out:
# 0    29.0000
# 1     0.9167
# 2     2.0000
# 3    30.0000
# 4    25.0000
# Name: age, dtype: float64

# %%
###What is the 'category' Dtype used for?
#It's used when a column has a limited number of text options.
#Example: Sex has two categories, male and female

###Object is different from category. Object can include any sort of text, any arrangement.
#Category = limited, Male or Female , survived or died, embarked - S, C, Q, ?

# %%
#Start with pd_to_numeric... https://www.udemy.com/course/python-data-analysis-visualization/learn/lecture/29504892#overview

# %%
###If pd_to_numeric finds an error, such as a '?' that it can't convert to a number
###then you can 'coerce' it and it will be set as NaN

# %%
titanic = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/titanic.csv')
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
###You can simply pass in the series that you want to convert to numbers
#to pass in a series, use titanic['age]

#pd.to_numeric(titanic['age'])   ###this gives an error b/c pandas doesn't know what to do with '?' marks
#let's use the errors 'coerce' to fix this
pd.to_numeric(titanic['age'], errors='coerce')
#then you can save it
titanic['age'] = pd.to_numeric(titanic['age'], errors='coerce')
titanic.head(2)
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...    ?                     St Louis, MO
# 1       1         1  ...    ?  Montreal, PQ / Chesterville, ON
#
# [2 rows x 14 columns]

# %%
###You can use to_numeric to convert a series to numeric
#and you can tell it that if it has objects, like the '?' mark, then covert it to NaN
#so that it's a None type and still works

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
###we can see that there are a lot of Null values in 'age' b/c there were a lot of question marks in there

# %%
#Now that it's numeric, we can do calculations on it and get numeric data

titanic['age'].describe()
# Out:
# count    1046.000000
# mean       29.881135
# std        14.413500
# min         0.166700
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: age, dtype: float64

# %%
stats = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/game_stats.csv')
stats.head(2)
# Out:
#      name league  points  assists  rebounds
# 0     bob    nba    22.0      5.0      10.0
# 1  jessie    NaN    10.0      NaN       2.0

# %%
stats.head(2).isna()
# Out:
#     name  league  points  assists  rebounds
# 0  False   False   False    False     False
# 1  False    True   False     True     False

# %%
#we can also check what values in a series (column) isna()
stats.league.isna()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# Name: league, dtype: bool

# %%
### We can also check which rows don't have a league by plugging the above into stats ###

stats[stats['league'].isna()]
# Out:
#        name league  points  assists  rebounds
# 1    jessie    NaN    10.0      NaN       2.0
# 4  timothee    NaN     8.0      NaN       NaN
# 6       NaN    NaN     NaN      NaN       NaN

# %%
#Start at 3min: https://www.udemy.com/course/python-data-analysis-visualization/learn/lecture/29504898#overview
#at dropna

# %%
stats.head(3)
# Out:
#      name      league  points  assists  rebounds
# 0     bob         nba    22.0      5.0      10.0
# 1  jessie         NaN    10.0      NaN       2.0
# 2     stu  euroleague     NaN      NaN       NaN

# %%
stats['assists'].dropna()  #You can save it inplace or into a variable if you want to save those non-NaN values
#then it will just show you the assists ros with no NaNs
# Out:
# 0    5.0
# 5    8.0
# Name: assists, dtype: float64

# %%
stats.dropna()   #by defaults drops the rows with 'any' NaN
# Out:
#     name league  points  assists  rebounds
# 0    bob    nba    22.0      5.0      10.0
# 5  steph    nba    49.0      8.0      10.0

# %%
#the rows above have no NaNs in them

#You can instead specify to only drop the rows if all the values in the rows are NaN

stats.dropna(how='all')   #doesn't drop any rows in this case b/c there's no row where 'all' the values are NaN
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie         NaN    10.0      NaN       2.0
# 2       stu  euroleague     NaN      NaN       NaN
# 3   jackson         aba     9.0      NaN       2.0
# 4  timothee         NaN     8.0      NaN       NaN
# 5     steph         nba    49.0      8.0      10.0

# %%
#You can also ask it only to look at certain columns with the subset paremeter.

# %%
#What's another option, beyond dropna()???

stats.fillna(0)  #You can use fillna to fill any NaNs with any number (such as the mean).
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie           0    10.0      0.0       2.0
# 2       stu  euroleague     0.0      0.0       0.0
# 3   jackson         aba     9.0      0.0       2.0
# 4  timothee           0     8.0      0.0       0.0
# 5     steph         nba    49.0      8.0      10.0
# 6         0           0     0.0      0.0       0.0

# %%
###We probably don't want to fill the league values with 0, so how can we fill them with 'amateur'?

stats['league'].fillna('amateur', inplace=True)

# %%
stats
# Out:
#        name      league  points  assists  rebounds
# 0       bob         nba    22.0      5.0      10.0
# 1    jessie     amateur    10.0      NaN       2.0
# 2       stu  euroleague     NaN      NaN       NaN
# 3   jackson         aba     9.0      NaN       2.0
# 4  timothee     amateur     8.0      NaN       NaN
# 5     steph         nba    49.0      8.0      10.0
# 6       NaN     amateur     NaN      NaN       NaN

# %%
### How can you use .fillna for two values at the same time???

stats.fillna({'points': 0, 'assists': 'NONE'})
# Out:
#        name      league  points assists  rebounds
# 0       bob         nba    22.0     5.0      10.0
# 1    jessie     amateur    10.0    NONE       2.0
# 2       stu  euroleague     0.0    NONE       NaN
# 3   jackson         aba     9.0    NONE       2.0
# 4  timothee     amateur     8.0    NONE       NaN
# 5     steph         nba    49.0     8.0      10.0
# 6       NaN     amateur     0.0    NONE       NaN

# %%
sales = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/sales.csv')
sales.head()
# Out:
#    rating  shipping_zip  billing_zip
# 0     5.0           NaN      81220.0
# 1     4.5       94931.0      94931.0
# 2     NaN       92625.0      92625.0
# 3     4.5       10003.0      10003.0
# 4     4.0           NaN      92660.0

# %%
###How can we fill the NaN shipping_zips with the subsequent billing_zip?

#sales = sales['shipping_zip'].fillna(sales['billing_zip'], inplace=True)
###You're filling it with the series

###Now it's getting NoneType object is not subscriptable b/c I already saved it inplace.
#I think that I'd have to reload the df to go back a step

# %%
#sales.head()
#AttributeError: 'NoneType' object has no attribute 'head'

# %%
#Challenges:

#1. Find the rows in the netflix dataset that are missing a country

netflix.country.isna()
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 8802    False
# 8803     True
# 8804    False
# 8805    False
# 8806    False
# Name: country, Length: 8807, dtype: bool

# %%
#Find the rows with no director, cast, AND country listed

netflix[netflix.country.isna() & netflix.director.isna() & netflix.cast.isna()]
# Out:
#      show_id  ...                                        description
# 3         s4  ...  Feuds, flirtations and toilet talk go down amo...
# 10       s11  ...  Sicily boasts a bold "Anti-Mafia" coalition. B...
# 14       s15  ...  Cameras following Bengaluru police on the job ...
# 74       s75  ...  With an eye for every budget, three travelers ...
# 123     s124  ...  Based on the last book of the epic Ramayana, t...
# ...      ...  ...                                                ...
# 7812   s7813  ...  Eight women perform in front of celebrity judg...
# 8109   s8110  ...  From Spain's countryside to Scotland's stony t...
# 8199   s8200  ...  A single man searches for his soulmate through...
# 8609   s8610  ...  Australia's toughest tow truck operators work ...
# 8803   s8804  ...  While living alone in a spooky town, a young g...
#
# [96 rows x 12 columns]

# %%
#Drop all the rows in the df that have at least one NA value (not inplace!)
netflix.dropna()
# Out:
#      show_id  ...                                        description
# 7         s8  ...  On a photo shoot in Ghana, an American model s...
# 8         s9  ...  A talented batch of amateur bakers face off in...
# 9        s10  ...  A woman adjusting to life after a loss contend...
# 12       s13  ...  After most of her family is murdered in a terr...
# 24       s25  ...  When the father of the man she loves insists t...
# ...      ...  ...                                                ...
# 8801   s8802  ...  Recovering alcoholic Talal wakes up inside a s...
# 8802   s8803  ...  A political cartoonist, a crime reporter and a...
# 8804   s8805  ...  Looking to survive in a world taken over by zo...
# 8805   s8806  ...  Dragged from civilian life, a former superhero...
# 8806   s8807  ...  A scrappy but poor boy worms his way into a ty...
#
# [5332 rows x 12 columns]

# %%
#Drop all columns in the df that contain at least one NA value, not inplace!

netflix.dropna(axis=1)
# Out:
#      show_id  ...                                        description
# 0         s1  ...  As her father nears the end of his life, filmm...
# 1         s2  ...  After crossing paths at a party, a Cape Town t...
# 2         s3  ...  To protect his family from a powerful drug lor...
# 3         s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4         s5  ...  In a city of coaching centers known to train I...
# ...      ...  ...                                                ...
# 8802   s8803  ...  A political cartoonist, a crime reporter and a...
# 8803   s8804  ...  While living alone in a spooky town, a young g...
# 8804   s8805  ...  Looking to survive in a world taken over by zo...
# 8805   s8806  ...  Dragged from civilian life, a former superhero...
# 8806   s8807  ...  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 6 columns]

# %%
#Drop all rows int he dataset that have a missing director or cast (not inplace!)

netflix.dropna(subset=['director', 'cast'])
# Out:
#      show_id  ...                                        description
# 2         s3  ...  To protect his family from a powerful drug lor...
# 5         s6  ...  The arrival of a charismatic young priest brin...
# 6         s7  ...  Equestria's divided. But a bright-eyed hero be...
# 7         s8  ...  On a photo shoot in Ghana, an American model s...
# 8         s9  ...  A talented batch of amateur bakers face off in...
# ...      ...  ...                                                ...
# 8801   s8802  ...  Recovering alcoholic Talal wakes up inside a s...
# 8802   s8803  ...  A political cartoonist, a crime reporter and a...
# 8804   s8805  ...  Looking to survive in a world taken over by zo...
# 8805   s8806  ...  Dragged from civilian life, a former superhero...
# 8806   s8807  ...  A scrappy but poor boy worms his way into a ty...
#
# [5700 rows x 12 columns]

# %%
# Find the rows that are missing a 'rating'
# Replace the na ratings with 'TV-MA' USING .loc()

netflix.loc[netflix['rating'].isna(), 'rating'] = 'TV-MA'

# %%
#Check if there are any left that are any 'ratings' left that are .na()

netflix.loc[netflix['rating'].isna()]
#shows are there are no rows in rating that are still .isna()
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
mode_country = netflix['country'].mode()[0]   ###This is a very common way of filling in the missing values with the most common value

# %%
#netflix['country'].mode()

# %%
netflix.fillna({'country': mode_country}, inplace=True)
